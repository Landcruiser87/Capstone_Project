# %%
import pandas as pd
import os 
import numpy as np
import matplotlib.pyplot as plt
import csv
import seaborn as sns

# %%
df4 = pd.read_csv('/Users/samanthasprague/Downloads/ComboPlatter_New.csv')

# %%
df4 = pd.DataFrame(df4)

# %%
df4.head
# Out:
# <bound method DataFrame.head of       TimeStamp_s  exercise_amt  exercise_id  sID1_AccX_g  sID1_AccY_g  \
# 0          0.0000            25            1     0.259705    -0.943461
# 1          0.0025            25            1     0.256628    -0.944817
# 2          0.0050            25            1     0.254661    -0.945341
# 3          0.0075            25            1     0.254658    -0.946851
# 4          0.0100            25            1     0.256257    -0.946479
# 5          0.0125            25            1     0.258113    -0.944342
# 6          0.0150            25            1     0.259101    -0.944805
# 7          0.0325            25            1     0.261090    -0.940239
# 8          0.0350            25            1     0.256032    -0.942668
# 9          0.0375            25            1     0.253058    -0.946949
# 10         0.0400            25            1     0.248243    -0.951797
# 11         0.0425            25            1     0.248217    -0.957721
# ...

# %%
df4.columns
# Out:
# Index([u'TimeStamp_s', u'exercise_amt', u'exercise_id', u'sID1_AccX_g',
#        u'sID1_AccY_g', u'sID1_AccZ_g', u'sID1_EulerX_deg', u'sID1_EulerY_deg',
#        u'sID1_EulerZ_deg', u'sID1_GyroX_deg/s', u'sID1_GyroY_deg/s',
#        u'sID1_GyroZ_deg/s', u'sID1_LinAccX_g', u'sID1_LinAccY_g',
#        u'sID1_LinAccZ_g', u'sID1_MagX_uT', u'sID1_MagY_uT', u'sID1_MagZ_uT',
#        u'sID1_QuatW', u'sID1_QuatX', u'sID1_QuatY', u'sID1_QuatZ',
#        u'sID2_AccX_g', u'sID2_AccY_g', u'sID2_AccZ_g', u'sID2_EulerX_deg',
#        u'sID2_EulerY_deg', u'sID2_EulerZ_deg', u'sID2_GyroX_deg/s',
#        u'sID2_GyroY_deg/s', u'sID2_GyroZ_deg/s', u'sID2_LinAccX_g',
#        u'sID2_LinAccY_g', u'sID2_LinAccZ_g', u'sID2_MagX_uT', u'sID2_MagY_uT',
#        u'sID2_MagZ_uT', u'sID2_QuatW', u'sID2_QuatX', u'sID2_QuatY',
#        u'sID2_QuatZ', u'sID3_AccX_g', u'sID3_AccY_g', u'sID3_AccZ_g',
#        u'sID3_EulerX_deg', u'sID3_EulerY_deg', u'sID3_EulerZ_deg',
# ...

# %%
#ankle is sID1
#SNS plots for sID1

# %%
#X

# %%
sns.set()
sns.relplot(x="TimeStamp_s", y="sID1_AccX_g", facet_kws=dict(sharex=False),
            kind="line", legend="full", data=df4);

# %%
#Y

# %%
sns.set()
sns.relplot(x="TimeStamp_s", y="sID1_AccY_g", facet_kws=dict(sharex=False),
            kind="line", legend="full", data=df4);

# %%
#Z

# %%
sns.set()
sns.relplot(x="TimeStamp_s", y="sID1_AccZ_g", facet_kws=dict(sharex=False),
            kind="line", legend="full", data=df4);

# %%
#waist is sID2
#SNS plots for sID2

# %%
#x

# %%
sns.set()
sns.relplot(x="TimeStamp_s", y="sID2_AccX_g", facet_kws=dict(sharex=False),
            kind="line", legend="full", data=df4);

# %%
#y

# %%
sns.set()
sns.relplot(x="TimeStamp_s", y="sID2_AccY_g", facet_kws=dict(sharex=False),
            kind="line", legend="full", data=df4);

# %%
#z

# %%
sns.set()
sns.relplot(x="TimeStamp_s", y="sID2_AccZ_g", facet_kws=dict(sharex=False),
            kind="line", legend="full", data=df4);

# %%
#write is sID3
#SNS plots for sID3

# %%
#x

# %%
sns.set()
sns.relplot(x="TimeStamp_s", y="sID3_AccX_g", facet_kws=dict(sharex=False),
            kind="line", legend="full", data=df4);

# %%
#y

# %%
sns.set()
sns.relplot(x="TimeStamp_s", y="sID3_AccY_g", facet_kws=dict(sharex=False),
            kind="line", legend="full", data=df4);

# %%
#z

# %%
sns.set()
sns.relplot(x="TimeStamp_s", y="sID3_AccZ_g", facet_kws=dict(sharex=False),
            kind="line", legend="full", data=df4);

# %%
#2D Plots of sID1

# %%
combSensorAcc = pd.DataFrame(df4, columns=['sID1_AccX_g', 'sID1_AccY_g', 'sID1_AccZ_g'])
for col in combSensorAcc:
    plt.hist(combSensorAcc[col])

# %%
for col in combSensorAcc:
    sns.kdeplot(combSensorAcc[col], shade=True)

# %%
combSensorAcc.head()
# Out:
#    sID1_AccX_g  sID1_AccY_g  sID1_AccZ_g
# 0     0.259705    -0.943461     0.217038
# 1     0.256628    -0.944817     0.218712
# 2     0.254661    -0.945341     0.220894
# 3     0.254658    -0.946851     0.223181
# 4     0.256257    -0.946479     0.222460

# %%
#2D Plots of sID2

# %%
combSensorAcc2 = pd.DataFrame(df4, columns=['sID2_AccX_g', 'sID2_AccY_g', 'sID2_AccZ_g'])
for col in combSensorAcc2:
    plt.hist(combSensorAcc2[col])

# %%
for col in combSensorAcc2:
    sns.kdeplot(combSensorAcc2[col], shade=True)

# %%
#2D plots of sID3
#combSensorAcc3

# %%
combSensorAcc3 = pd.DataFrame(df4, columns=['sID3_AccX_g', 'sID3_AccX_g', 'sID3_AccX_g'])
for col in combSensorAcc3:
    plt.hist(combSensorAcc3[col])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-104-45c498785667> in <module>()
#       1 combSensorAcc3 = pd.DataFrame(df4, columns=['sID3_AccX_g', 'sID3_AccX_g', 'sID3_AccX_g'])
#       2 for col in combSensorAcc3:
# ----> 3     plt.hist(combSensorAcc3[col])
#
# /Users/samanthasprague/anaconda2/envs/python3/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3135                       histtype=histtype, align=align, orientation=orientation,
#    3136                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3137                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3138     finally:
#    3139         ax._hold = washold
#
# ...

# %%
for col in combSensorAcc3:
    sns.kdeplot(combSensorAcc3[col], shade=True)

# %%
#3D Plots

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
#3d plot of combSensorAcc x,y,z

# %%
plot3d = plt.figure().gca(projection='3d')
X=combSensorAcc['sID1_AccX_g']
Y=combSensorAcc['sID1_AccY_g']
Z=combSensorAcc['sID1_AccZ_g']
plot3d.scatter(X, Y, Z, c='r')
plot3d.set_xlabel('sID1_AccX_g')
plot3d.set_ylabel('sID1_AccY_g')
plot3d.set_zlabel('sID1_AccZ_g')
plt.show()

# %%
#3d plot of combSensorAcc1,2,3 x,y,z

# %%
plot3d = plt.figure().gca(projection='3d')
X=combSensorAcc['sID1_AccX_g']
Y=combSensorAcc['sID1_AccY_g']
Z=combSensorAcc['sID1_AccZ_g']
X2=combSensorAcc2['sID2_AccX_g']
Y2=combSensorAcc2['sID2_AccY_g']
Z2=combSensorAcc2['sID2_AccZ_g']
X3=combSensorAcc3['sID3_AccX_g']
Y3=combSensorAcc3['sID3_AccY_g']
Z3=combSensorAcc3['sID3_AccZ_g']
plot3d.scatter(X, Y, Z, c='r')
plot3d.scatter(X2, Y2, Z2, c='b')
plot3d.scatter(X3, Y3, Z3, c='g')
plot3d.set_xlabel('X')
plot3d.set_ylabel('Y')
plot3d.set_zlabel('Z')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-b150123a6eee> in <module>()
#       7 Z2=combSensorAcc2['sID2_AccZ_g']
#       8 X3=combSensorAcc3['sID3_AccX_g']
# ----> 9 Y3=combSensorAcc3['sID3_AccY_g']
#      10 Z3=combSensorAcc3['sID3_AccZ_g']
#      11 plot3d.scatter(X, Y, Z, c='r')
#
# /Users/samanthasprague/anaconda2/envs/python3/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /Users/samanthasprague/anaconda2/envs/python3/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
# ...

# %%
#3d plot of combSensorAcc3 x,y,z

# %%
plot3d = plt.figure().gca(projection='3d')
plot3d.scatter(combSensorAcc3['sID3_AccX_g'],combSensorAcc3['sID3_AccY_g'],combSensorAcc3['sID3_AccZ_g'])
plot3d.set_xlabel('sID3_AccX_g')
plot3d.set_ylabel('sID3_AccY_g')
plot3d.set_zlabel('sID3_AccZ_g')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-57aaf04f6b0f> in <module>()
#       1 plot3d = plt.figure().gca(projection='3d')
# ----> 2 plot3d.scatter(combSensorAcc3['sID3_AccX_g'],combSensorAcc3['sID3_AccY_g'],combSensorAcc3['sID3_AccZ_g'])
#       3 plot3d.set_xlabel('sID3_AccX_g')
#       4 plot3d.set_ylabel('sID3_AccY_g')
#       5 plot3d.set_zlabel('sID3_AccZ_g')
#
# NameError: name 'combSensorAcc3' is not defined

# %%
df = pd.read_csv('/Users/samanthasprague/Downloads/ex1.csv')

# %%
df.head()
# Out:
#   model_type  accuracy
# 0       LSTM        90
# 1        RNN        80
# 2        GRU        94

# %%
#MATPLOTLIB -- sucky

# %%
colors = {'LSTM':'r', 'RNN':'g', 'GRU':'b'}
# create a figure and axis
fig, ax = plt.subplots()
# plot each data-point
for i in range(len(df['model_type'])):
    ax.scatter(df['model_type'][i], df['accuracy'][i],color=colors[df['model_type'][i]])
# set a title and labels
ax.set_title('Model Accuracy')
ax.set_xlabel('Model Type')
ax.set_ylabel('Accuracy')
# Out:
# Text(0,0.5,'Accuracy')

# %%
#PANDAS VIZ - BETTER, kinda clunky

# %%
df.plot.line(title='Model Accuracies')

# %%
df['accuracy'].plot.hist(title='Model Accuracies')

# %%
df.plot.hist(subplots=True, layout=(2,2), figsize=(10, 10), bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a24adb8d0>,
# ...
#       dtype=object)

# %%
df['model_type'].value_counts().sort_index().plot.barh()

# %%
#SEABORN - BETTER

# %%
sns.scatterplot(x='model_type', y='accuracy', hue='model_type', data=df)

# %%
sns.lineplot(data=df['accuracy'])

# %%
#boxplot 
df = wine_reviews[(wine_reviews['points']>=95) & (wine_reviews['price']<1000)]
sns.boxplot('points', 'price', data=df)

# %%
sns.heatmap(df.corr(), annot=True)

# %%
df2 = pd.read_csv('/Users/samanthasprague/Downloads/ex2.csv')

# %%
sns.lineplot(data=df2['accuracy'])

# %%
df3 = pd.read_csv('/Users/samanthasprague/Downloads/ex3.csv')

# %%
colors = {'LSTM':'r', 'RNN':'g', 'GRU':'b'}
# create a figure and axis
fig, ax = plt.subplots()
# plot each data-point
for i in range(len(df3['model_type'])):
    ax.scatter(df3['model_type'][i], df3['accuracy'][i],color=colors[df3['model_type'][i]])
# set a title and labels
ax.set_title('Model Accuracy')
ax.set_xlabel('Model Type')
ax.set_ylabel('Accuracy')
# Out:
# Text(0,0.5,'Accuracy')

# %%
# THIS IS POSITION DATA FOR EXERCISE 1

# %%
df5 = pd.read_csv('/Users/samanthasprague/Downloads/exercise1.csv')

# %%
df5.head()
# Out:
#   position     value
# 0        X  0.259705
# 1        X  0.256628
# 2        X  0.254661
# 3        X  0.254658
# 4        X  0.256257

# %%
sns.scatterplot(x='position', y='value', hue='position', data=df5)

# %%
sns.set_style("whitegrid");
sns.pairplot(df5, hue="position", size=3);
plt.show()

# %%
df6 = pd.read_csv('/Users/samanthasprague/Downloads/exercise2.csv')

# %%
df6.head()
# Out:
#   position     value  Unnamed: 2
# 0        X  0.334354   -0.146198
# 1        X  0.334133   -0.141472
# 2        X  0.331570   -0.137742
# 3        X  0.329500   -0.135704
# 4        X  0.329248   -0.136701

# %%
sns.scatterplot(x='position', y='value', hue='position', data=df6)

# %%
sns.set_style("whitegrid");
sns.pairplot(df6, hue="position", size=3);
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-21-00515579c4b4> in <module>()
#       1 sns.set_style("whitegrid");
# ----> 2 sns.pairplot(df6, hue="position", size=3);
#       3 plt.show()
#
# /Users/samanthasprague/anaconda2/envs/python3/lib/python2.7/site-packages/seaborn/axisgrid.pyc in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2109             diag_kws.setdefault("shade", True)
#    2110             diag_kws["legend"] = False
# -> 2111             grid.map_diag(kdeplot, **diag_kws)
#    2112
#    2113     # Maybe plot on the off-diagonals
#
# /Users/samanthasprague/anaconda2/envs/python3/lib/python2.7/site-packages/seaborn/axisgrid.pyc in map_diag(self, func, **kwargs)
#    1397                     color = fixed_color
#    1398
# ...
